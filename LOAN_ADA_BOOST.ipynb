# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.simplefilter("ignore")

# %%
df=pd.read_csv("CleanedLoanData.csv")

# %%
df.head()
# Out:
#    person_age  person_education  person_income  person_emp_exp  loan_amnt  \
# 0    0.400888                 3       7.116215               0  44.928204
# 1    0.400869                 2       6.401416               0  17.192952
# 2    0.400930                 2       6.406924               3  27.675832
# 3    0.400904                 0       7.154530               0  44.928204
# 4    0.400918                 3       7.084614               1  44.928204
#
#    loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0          16.02             0.181480                         3.0
# 1          11.14             0.064705                         2.0
# 2          12.87             0.175681                         3.0
# 3          15.23             0.175681                         2.0
# 4          14.27             0.185389                         4.0
#
#    credit_score  loan_status  person_gender_male  person_home_ownership_OTHER  \
# 0           561            1               False                        False
# 1           504            0               False                        False
# 2           635            1               False                        False
# 3           675            1               False                        False
# 4           586            1                True                        False
#
#    person_home_ownership_OWN  person_home_ownership_RENT  \
# 0                      False                        True
# 1                       True                       False
# 2                      False                       False
# 3                      False                        True
# 4                      False                        True
#
#    loan_intent_EDUCATION  loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  \
# 0                  False                        False                False
# 1                   True                        False                False
# 2                  False                        False                 True
# 3                  False                        False                 True
# 4                  False                        False                 True
#
#    loan_intent_PERSONAL  loan_intent_VENTURE  \
# 0                  True                False
# 1                 False                False
# 2                 False                False
# 3                 False                False
# 4                 False                False
#
#    previous_loan_defaults_on_file_Yes
# 0                               False
# 1                                True
# 2                               False
# 3                               False
# 4                               False

# %%
x=df.drop("loan_status",axis=1)
y=df["loan_status"]

# %%
contnious=["person_age","person_income","loan_amnt","loan_int_rate","loan_percent_income",
          "credit_score"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=77)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train[contnious]=sc.fit_transform(x_train[contnious])
x_test[contnious]=sc.transform(x_test[contnious])

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV

estimators=AdaBoostClassifier(random_state=True)
param_grids={"n_estimators":list(range(1,71))}
grid=GridSearchCV(estimators,param_grids,cv=5,scoring="accuracy")
grid.fit(x_train,y_train)
grid.best_params_
# Out:
# {'n_estimators': 56}

# %%
newDF=pd.DataFrame(grid.best_estimator_.feature_importances_,
                   columns=["Important_Feature"],
                   index=x_train.columns.tolist()
                  )
newDF
# Out:
#                                     Important_Feature
# person_age                                       0.00
# person_education                                 0.00
# person_income                                    0.22
# person_emp_exp                                   0.02
# loan_amnt                                        0.12
# loan_int_rate                                    0.24
# loan_percent_income                              0.08
# cb_person_cred_hist_length                       0.00
# credit_score                                     0.12
# person_gender_male                               0.00
# person_home_ownership_OTHER                      0.00
# person_home_ownership_OWN                        0.04
# person_home_ownership_RENT                       0.04
# loan_intent_EDUCATION                            0.04
# loan_intent_HOMEIMPROVEMENT                      0.00
# loan_intent_MEDICAL                              0.00
# loan_intent_PERSONAL                             0.02
# loan_intent_VENTURE                              0.04
# previous_loan_defaults_on_file_Yes               0.02

# %%
imp=newDF[newDF["Important_Feature"]>0].index.tolist()

# %%
x_train=x_train[imp]
x_test=x_test[imp]

# %%
#Modelling
from sklearn.ensemble import AdaBoostClassifier
model=AdaBoostClassifier(random_state=45,n_estimators= 56)
model.fit(x_train,y_train)

#Prediction
ypredTrain=model.predict(x_train)
ypredTest=model.predict(x_test)


#Accuracy
from sklearn.metrics import accuracy_score
TrainAccuracy=accuracy_score(y_train,ypredTrain)
TestAccuracy=accuracy_score(y_test,ypredTest)

#CrossVal
from sklearn.model_selection import cross_val_score
TrainCV=cross_val_score(model,x_train,y_train,cv=5,scoring="accuracy").mean()

#print
print("TrainAccuracy: ",TrainAccuracy," ","TestAccuracy: ",TestAccuracy," ","TrainCV",TrainCV)
# Out:
# TrainAccuracy:  0.9165462829203245   TestAccuracy:  0.9109901100122236   TrainCV 0.914934925375438
